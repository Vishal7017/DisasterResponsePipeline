# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import re
import numpy as np
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from joblib import dump

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('categorized_messages', engine)

# %%
# checking if there are any columns with only one single value
df.nunique()[df.nunique()==1]
# Out:
# child_alone    1
# dtype: int64

# %%
# droping columns with no value for model

X = df['message']
y = df.drop(columns=['id','message','original','genre', 'child_alone'])
category_names = y.columns.tolist()

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    '''
    INPUT - text (string)
    OUTPUT - tokenized and cleansed text (string)
    
    This function tokenizes and cleanses a string by the following steps:
        1. any url will be replaced by the string 'urlplaceholder'
        2. any puctuation and capitalization will be removed
        3. the text will be tokenized
        4. any stopword will be removed
        5. each word will be first lemmatized and then stemmed    
    '''
    
    # get list of all urls using regex
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    
    # replace each url in text string with placeholder
    for url in detected_urls:
        text = text.replace(url, 'urlplaceholder')

    # Remove punctuation characters
    text = re.sub(r'[^a-zA-Z0-9äöüÄÖÜß ]', '', text.lower())
    
    # tokenize
    tokens = word_tokenize(text)
    
    # Remove stop words
    tokens = [tok for tok in tokens if tok not in stopwords.words("english")]

    # instantiate lemmatizer and stemmer
    lemmatizer = WordNetLemmatizer()

    # lemmatize and stemm
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
def init_pipelines():
    '''
    Input - None
    Output - list of ML pipelines
    
    This function instantiates ML pipelines including a CountVectorizer including the above created tokenize udf, a tfidf and a ML classifier. 
    The first element in the list will include a RandomForestClassifier, the second a GradientBoosingClassifier and the third a AdaBoostClassifier. 
    '''

    #Random Forest Classifier Pipeline
    pipe_rfc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier()))
    ])

    #Gradient Boost Classifier Pipeline
    pipe_gbc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(GradientBoostingClassifier()))
    ])

    #ADA Boost Classifier Pipeline 
    pipe_abc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
    ])

    pipelines = [pipe_rfc, pipe_gbc, pipe_abc]
    
    return pipelines

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
def train_pipeline(pipeline, X_train_array, y_train_array, n_jobs=-1):
    '''
    INPUT:
    pipeline - ML pipeline
    X_train_array - a np-array of training features
    y_train_array - a np-array of training responses
    n_jobs - number of workers to be used by the classifer (default = -1)
    
    OUTPUT:
    pipeline - a fit pipeline
    
    This function fits the input pipeline to the input X and y array. 
    '''

    #setting pipeline parameters
    if 'clf__estimator__n_jobs' in pipeline.get_params():
        pipeline.set_params(clf__estimator__n_jobs=n_jobs)
    
    #fitting pipeline
    pipeline.fit(X_train_array, y_train_array)
    
    return pipeline

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def eval_pipeline(pipeline, X_test_array, y_test, column_names):
    '''
    INPUT:
    pipeline - ML pipeline
    X_test_array - a np-array of testing features
    y_train_array - a np-array of testing responses
    column_names - a list of column names of the features array/df
    
    OUTPUT:
    a classification report for each feature will be printed out. 
    '''
    
    #predicting y_test
    y_pred = pd.DataFrame(pipeline.predict(X_test_array), columns=y_train.columns.tolist())
        
    #classifier used:
    classifier_name = str(pipeline.get_params()['steps'][2][1]).replace('(','').replace(')','').replace('n_jobs','').split('=')[1]
    
    #printing classification report
    print('_________________________________ {} ___________________________________________________\n'.format(classifier_name))
    for i, col in enumerate(y_test):
        print('{}\n{}'.format(col, classification_report(y_test[col], y_pred[col], zero_division=0)))
        
    print('_______________________________________________________________________________________')
    print('Classification report in total')
    print(classification_report(y_test.melt().value, y_pred.melt().value, zero_division=0))
        
    print('____________________________________________________________________________________\n')

# %%
#instantiation of the pipelines
pipelines = init_pipelines()

#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)
#converting of train and test df into np-array
X_train_array, y_train_array, X_test_array = np.array(X_train), np.array(y_train), np.array(X_test)

#creation of a list of feature names
column_names = y_train.columns.tolist()

#fitting and evaluation of each pipeline in pipeline list
for pipe in pipelines:
    pipe = train_pipeline(pipe, X_train_array, y_train_array)
    eval_pipeline(pipe, X_test_array, y_test, column_names)
# Out:
# _________________________________ RandomForestClassifier ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.70      0.42      0.52      1853
#            1       0.84      0.95      0.89      6012
#
#     accuracy                           0.82      7865
#    macro avg       0.77      0.68      0.71      7865
# weighted avg       0.81      0.82      0.80      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      6552
#            1       0.84      0.49      0.62      1313
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.90      0.90      0.89      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81      4610
#            1       0.75      0.67      0.71      3255
#
#     accuracy                           0.77      7865
#    macro avg       0.77      0.76      0.76      7865
# weighted avg       0.77      0.77      0.77      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7236
#            1       0.60      0.10      0.17       629
#
#     accuracy                           0.92      7865
#    macro avg       0.76      0.55      0.56      7865
# weighted avg       0.90      0.92      0.90      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7459
#            1       0.79      0.08      0.14       406
#
#     accuracy                           0.95      7865
#    macro avg       0.87      0.54      0.56      7865
# weighted avg       0.94      0.95      0.93      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7663
#            1       0.61      0.05      0.10       202
#
#     accuracy                           0.97      7865
#    macro avg       0.79      0.53      0.54      7865
# weighted avg       0.97      0.97      0.96      7865
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7714
#            1       0.00      0.00      0.00       151
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7621
#            1       0.79      0.05      0.09       244
#
#     accuracy                           0.97      7865
#    macro avg       0.88      0.52      0.54      7865
# weighted avg       0.96      0.97      0.96      7865
#
# water
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7372
#            1       0.86      0.35      0.50       493
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.67      0.74      7865
# weighted avg       0.95      0.96      0.95      7865
#
# food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7004
#            1       0.84      0.62      0.71       861
#
#     accuracy                           0.95      7865
#    macro avg       0.90      0.80      0.84      7865
# weighted avg       0.94      0.95      0.94      7865
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7150
#            1       0.81      0.28      0.42       715
#
#     accuracy                           0.93      7865
#    macro avg       0.87      0.64      0.69      7865
# weighted avg       0.92      0.93      0.91      7865
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7751
#            1       0.78      0.06      0.11       114
#
#     accuracy                           0.99      7865
#    macro avg       0.88      0.53      0.55      7865
# weighted avg       0.98      0.99      0.98      7865
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7691
#            1       0.88      0.04      0.08       174
#
#     accuracy                           0.98      7865
#    macro avg       0.93      0.52      0.53      7865
# weighted avg       0.98      0.98      0.97      7865
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7777
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7588
#            1       0.33      0.01      0.01       277
#
#     accuracy                           0.96      7865
#    macro avg       0.65      0.50      0.50      7865
# weighted avg       0.94      0.96      0.95      7865
#
# death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7492
#            1       0.92      0.16      0.27       373
#
#     accuracy                           0.96      7865
#    macro avg       0.94      0.58      0.63      7865
# weighted avg       0.96      0.96      0.95      7865
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6831
#            1       0.61      0.04      0.07      1034
#
#     accuracy                           0.87      7865
#    macro avg       0.74      0.52      0.50      7865
# weighted avg       0.84      0.87      0.82      7865
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7371
#            1       0.50      0.00      0.01       494
#
#     accuracy                           0.94      7865
#    macro avg       0.72      0.50      0.49      7865
# weighted avg       0.91      0.94      0.91      7865
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7519
#            1       0.64      0.07      0.12       346
#
#     accuracy                           0.96      7865
#    macro avg       0.80      0.53      0.55      7865
# weighted avg       0.94      0.96      0.94      7865
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      7462
#            1       0.78      0.10      0.18       403
#
#     accuracy                           0.95      7865
#    macro avg       0.87      0.55      0.58      7865
# weighted avg       0.94      0.95      0.94      7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       1.00      0.02      0.05       168
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.51      0.52      7865
# weighted avg       0.98      0.98      0.97      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7814
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7791
#            1       0.00      0.00      0.00        74
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7767
#            1       0.00      0.00      0.00        98
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7531
#            1       0.25      0.00      0.01       334
#
#     accuracy                           0.96      7865
#    macro avg       0.60      0.50      0.49      7865
# weighted avg       0.93      0.96      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      5650
#            1       0.86      0.67      0.75      2215
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.81      0.84      7865
# weighted avg       0.88      0.88      0.87      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7202
#            1       0.90      0.43      0.58       663
#
#     accuracy                           0.95      7865
#    macro avg       0.92      0
# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
#creation of parameter dictionaries to be searched by grid search

params_rfc = {'tfidf__use_idf': [True],
              'clf__estimator__n_estimators':[100,200],
              'clf__estimator__min_samples_split':[2,5],
              'clf__estimator__n_jobs':[-1]
}

params_gbc = {'tfidf__use_idf': [True,False],
              'clf__estimator__n_estimators': [100, 200],
              'clf__estimator__learning_rate': [.05, .1]
}

params_abc = {'tfidf__use_idf': [True,False],
              'clf__estimator__n_estimators': [200, 300],
              'clf__estimator__learning_rate': [.15, .2]
}

params_gs = [params_rfc, params_gbc, params_abc]

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)
#converting of train and test df into np-array
X_train_array, y_train_array, X_test_array = np.array(X_train), np.array(y_train), np.array(X_test)
    
#creation of list of feature names
column_names = y_train.columns.tolist()

#istantiation of pipelines
pipelines = init_pipelines()
cv_list = []
results = []

#performing of grid search for each pipeline in pipeline list. the results and best estimators will be appended to the according list. 
for i, pipe in enumerate(pipelines):
    print(pipe)
    cv = GridSearchCV(pipe, param_grid=params_gs[i], verbose=3, return_train_score=True)
    cv.fit(X_train_array, y_train_array)
    cv_list.append(cv)
    results.append(cv.cv_results_)
    eval_pipeline(cv.best_estimator_, X_test_array, y_test, column_names)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.272), total= 7.8min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 10.2min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.994, test=0.268), total= 4.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 16.8min remaining:    0.0s
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.994, test=0.257), total= 4.5min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.994, test=0.265), total= 4.5min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.994, test=0.267), total= 5.6min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.272), total= 9.0min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.267), total= 9.2min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.258), total= 8.9min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.995, test=0.256), total= 6.7min
# [CV] clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=2, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.996, test=0.269), total= 6.2min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.915, test=0.272), total= 5.6min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.913, test=0.264), total= 5.7min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.914, test=0.254), total= 5.9min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.913, test=0.260), total= 5.8min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=100, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.914, test=0.265), total= 5.6min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.930, test=0.273), total= 8.0min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.932, test=0.265), total= 7.7min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.928, test=0.257), total= 9.1min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.929, test=0.261), total= 7.8min
# [CV] clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True
# [CV]  clf__estimator__min_samples_split=5, clf__estimator__n_estimators=200, clf__estimator__n_jobs=-1, tfidf__use_idf=True, score=(train=0.931, test=0.272), total= 7.7min
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 191.2min finished
# _________________________________ RandomForestClassifier ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.70      0.42      0.53      1853
#            1       0.84      0.95      0.89      6012
#
#     accuracy                           0.82      7865
#    macro avg       0.77      0.68      0.71      7865
# weighted avg       0.81      0.82      0.81      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      6552
#            1       0.83      0.50      0.62      1313
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.90      0.89      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82      4610
#            1       0.75      0.68      0.72      3255
#
#     accuracy                           0.78      7865
#    macro avg       0.77      0.76      0.77      7865
# weighted avg       0.78      0.78      0.77      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96      7236
#            1       0.57      0.07      0.13       629
#
#     accuracy                           0.92      7865
#    macro avg       0.75      0.53      0.55      7865
# weighted avg       0.90      0.92      0.89      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7459
#            1       0.75      0.07      0.12       406
#
#     accuracy                           0.95      7865
#    macro avg       0.85      0.53      0.55      7865
# weighted avg       0.94      0.95      0.93      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7663
#            1       0.65      0.06      0.12       202
#
#     accuracy                           0.98      7865
#    macro avg       0.81      0.53      0.55      7865
# weighted avg       0.97      0.98      0.97      7865
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7714
#            1       0.00      0.00      0.00       151
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7621
#            1       0.68      0.08      0.14       244
#
#     accuracy                           0.97      7865
#    macro avg       0.82      0.54      0.56      7865
# weighted avg       0.96      0.97      0.96      7865
#
# water
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7372
#            1       0.85      0.35      0.50       493
#
#     accuracy                           0.96      7865
#    macro avg       0.90      0.68      0.74      7865
# weighted avg       0.95      0.96      0.95      7865
#
# food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7004
#            1       0.85      0.55      0.67       861
#
#     accuracy                           0.94      7865
#    macro avg       0.90      0.77      0.82      7865
# weighted avg       0.94      0.94      0.93      7865
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      7150
#            1       0.81      0.36      0.49       715
#
#     accuracy                           0.93      7865
#    macro avg       0.88      0.67      0.73      7865
# weighted avg       0.93      0.93      0.92      7865
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7751
#            1       0.64      0.08      0.14       114
#
#     accuracy                           0.99      7865
#    macro avg       0.81      0.54      0.57      7865
# weighted avg       0.98      0.99      0.98      7865
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7691
#            1       0.88      0.04      0.08       174
#
#     accuracy                           0.98      7865
#    macro avg       0.93      0.52      0.53      7865
# weighted avg       0.98      0.98      0.97      7865
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7777
#            1       1.00      0.01      0.02        88
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.98      7865
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7588
#            1       0.69      0.03      0.06       277
#
#     accuracy                           0.97      7865
#    macro avg       0.83      0.52      0.52      7865
# weighted avg       0.96      0.97      0.95      7865
#
# death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7492
#            1       0.88      0.17      0.29       373
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.59      0.63      7865
# weighted avg       0.96      0.96      0.95      7865
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6831
#            1       0.71      0.05      0.09      1034
#
#     accuracy                           0.87      7865
#    macro avg       0.79      0.52      0.51      7865
# weighted avg       0.85      0.87      0.82      7865
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7371
#            1       0.50      0.00      0.01       494
#
#     accuracy                           0.94      7865
#    macro avg       0.72      0.50      0.49      7865
# weighted avg       0.91      0.94      0.91      7865
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7519
#            1       0.74      0.08      0.15       346
#
#     accuracy                           0.96      7865
#    macro avg       0.85      0.54      0.56      7865
# weighted avg       0.95      0.96      0.94      7865
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7462
#            1       0.79      0.14      0.24       403
#
#     accuracy                           0.95      7865
#    macro avg       0.87      0.57      0.61      7865
# weighted avg       0.95      0.95      0.94      7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       1.00      0.03      0.06       168
#
#     accuracy                           0.98      7865
#    macro avg       0.99      0.51      0.52      7865
# weighted avg       0.98      0.98      0.97      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7814
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7791
#            1       0.00      0.00      0.00        74
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7767
#            1       0.00      0.00      0.00        98
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7531
#            1       0.25      0.00      0.01       334
#
#     accuracy                           0.96      7865
#    macro avg       0.60      0.50      0.49      7865
# weighted avg       0.93      0.96      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      5650
#            1       0.86      0.68      0.76      2215
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.82      0.84      7865
# weighted avg       0.88      0.88      0.87      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7202
#            1       0.91      0.45      0.61       663
#
#     accuracy                           0.95      7865
#    macro avg       0.93      0.72      0.79      7865
# weighted avg       0.95      0.95      0.94      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7130
#            1       0.77      0.49      0.60       735
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.74      0.78      7865
# weighted avg       0.93      0.94      0.93      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7122
#            1       0.90      0.78      0.83       743
#
#     accuracy                           0.97      7865
#    macro avg       0.94      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7718
#            1       0.83      0.07      0.13       147
#
#     accuracy                           0.98      7865
#    macro avg       0.91      0.53      0.56      7865
# weighted avg       0.98      0.98      0.97      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7463
#            1       0.76      0.04      0.08       402
#
#     accuracy                           0.95      7865
#    macro avg       0.86      0.52      0.53      7865
# weighted avg       0.94      0.95      0.93      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6343
#            1       0.78      0.36      0.49      1522
#
#     accuracy                           0.86      7865
#    macro avg       0.82      0.67      0.70      7865
# weighted avg       0.85      0.86      0.83      7865
#
# _______________________________________________________________________________________
# Classification report in total
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    250388
#            1       0.82      0.53      0.64     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.89      0.76      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# ____________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier()))])
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.267, test=0.231), total= 7.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 10.2min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.273, test=0.223), total= 7.7min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 20.2min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.273, test=0.232), total= 7.7min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.270, test=0.229), total= 7.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.264, test=0.245), total= 7.6min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.269, test=0.238), total= 7.5min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.271, test=0.223), total= 7.3min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.272, test=0.240), total= 7.5min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.271, test=0.232), total= 7.6min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.263, test=0.245), total= 7.1min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.302, test=0.247), total=11.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.305, test=0.242), total=10.2min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.302, test=0.244), total=10.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.310, test=0.246), total=10.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.300, test=0.263), total=10.0min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.303, test=0.250), total= 9.8min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.307, test=0.242), total= 9.1min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.302, test=0.250), total= 9.1min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.310, test=0.249), total= 9.2min
# [CV] clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.05, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.299, test=0.260), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.312, test=0.237), total= 6.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.312, test=0.231), total= 6.6min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.311, test=0.237), total= 6.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.319, test=0.235), total= 6.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=True, score=(train=0.306, test=0.250), total= 6.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.311, test=0.241), total= 5.9min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.315, test=0.235), total= 6.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.311, test=0.244), total= 5.9min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.316, test=0.239), total= 6.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=100, tfidf__use_idf=False, score=(train=0.305, test=0.253), total= 6.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.356, test=0.251), total= 9.9min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.356, test=0.242), total=10.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.357, test=0.240), total=10.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.359, test=0.238), total= 8.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.354, test=0.259), total= 9.4min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.357, test=0.258), total= 9.0min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.357, test=0.241), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.357, test=0.250), total= 9.1min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.360, test=0.247), total= 8.3min
# [CV] clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.1, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.352, test=0.264), total= 7.5min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 411.5min finished
# _________________________________ GradientBoostingClassifiern_estimators ___________________________________________________
#
# related
#               precision    recall  f1-score   support
#
#            0       0.73      0.24      0.36      1853
#            1       0.81      0.97      0.88      6012
#
#     accuracy                           0.80      7865
#    macro avg       0.77      0.60      0.62      7865
# weighted avg       0.79      0.80      0.76      7865
#
# request
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      6552
#            1       0.83      0.50      0.62      1313
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.90      0.89      7865
#
# offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# aid_related
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81      4610
#            1       0.78      0.59      0.67      3255
#
#     accuracy                           0.76      7865
#    macro avg       0.76      0.73      0.74      7865
# weighted avg       0.76      0.76      0.75      7865
#
# medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      7236
#            1       0.62      0.22      0.32       629
#
#     accuracy                           0.93      7865
#    macro avg       0.78      0.60      0.64      7865
# weighted avg       0.91      0.93      0.91      7865
#
# medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7459
#            1       0.54      0.28      0.37       406
#
#     accuracy                           0.95      7865
#    macro avg       0.75      0.63      0.67      7865
# weighted avg       0.94      0.95      0.94      7865
#
# search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7663
#            1       0.30      0.24      0.27       202
#
#     accuracy                           0.97      7865
#    macro avg       0.64      0.61      0.62      7865
# weighted avg       0.96      0.97      0.96      7865
#
# security
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7714
#            1       0.09      0.04      0.05       151
#
#     accuracy                           0.97      7865
#    macro avg       0.53      0.52      0.52      7865
# weighted avg       0.96      0.97      0.97      7865
#
# military
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7621
#            1       0.44      0.20      0.28       244
#
#     accuracy                           0.97      7865
#    macro avg       0.71      0.60      0.63      7865
# weighted avg       0.96      0.97      0.96      7865
#
# water
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7372
#            1       0.74      0.66      0.69       493
#
#     accuracy                           0.96      7865
#    macro avg       0.86      0.82      0.84      7865
# weighted avg       0.96      0.96      0.96      7865
#
# food
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      7004
#            1       0.79      0.79      0.79       861
#
#     accuracy                           0.95      7865
#    macro avg       0.88      0.88      0.88      7865
# weighted avg       0.95      0.95      0.95      7865
#
# shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7150
#            1       0.76      0.54      0.63       715
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.76      0.80      7865
# weighted avg       0.94      0.94      0.94      7865
#
# clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7751
#            1       0.61      0.50      0.55       114
#
#     accuracy                           0.99      7865
#    macro avg       0.80      0.75      0.77      7865
# weighted avg       0.99      0.99      0.99      7865
#
# money
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7691
#            1       0.46      0.25      0.33       174
#
#     accuracy                           0.98      7865
#    macro avg       0.72      0.62      0.66      7865
# weighted avg       0.97      0.98      0.97      7865
#
# missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7777
#            1       0.11      0.08      0.09        88
#
#     accuracy                           0.98      7865
#    macro avg       0.55      0.54      0.54      7865
# weighted avg       0.98      0.98      0.98      7865
#
# refugees
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7588
#            1       0.43      0.29      0.35       277
#
#     accuracy                           0.96      7865
#    macro avg       0.70      0.64      0.66      7865
# weighted avg       0.96      0.96      0.96      7865
#
# death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7492
#            1       0.65      0.48      0.55       373
#
#     accuracy                           0.96      7865
#    macro avg       0.81      0.73      0.77      7865
# weighted avg       0.96      0.96      0.96      7865
#
# other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      6831
#            1       0.58      0.09      0.16      1034
#
#     accuracy                           0.87      7865
#    macro avg       0.73      0.54      0.55      7865
# weighted avg       0.84      0.87      0.83      7865
#
# infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7371
#            1       0.56      0.07      0.13       494
#
#     accuracy                           0.94      7865
#    macro avg       0.75      0.54      0.55      7865
# weighted avg       0.92      0.94      0.92      7865
#
# transport
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7519
#            1       0.52      0.20      0.29       346
#
#     accuracy                           0.96      7865
#    macro avg       0.74      0.59      0.63      7865
# weighted avg       0.94      0.96      0.95      7865
#
# buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7462
#            1       0.74      0.34      0.47       403
#
#     accuracy                           0.96      7865
#    macro avg       0.85      0.67      0.72      7865
# weighted avg       0.95      0.96      0.95      7865
#
# electricity
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7697
#            1       0.43      0.21      0.28       168
#
#     accuracy                           0.98      7865
#    macro avg       0.71      0.60      0.63      7865
# weighted avg       0.97      0.98      0.97      7865
#
# tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7814
#            1       0.03      0.02      0.03        51
#
#     accuracy                           0.99      7865
#    macro avg       0.51      0.51      0.51      7865
# weighted avg       0.99      0.99      0.99      7865
#
# hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7791
#            1       0.10      0.08      0.09        74
#
#     accuracy                           0.98      7865
#    macro avg       0.54      0.54      0.54      7865
# weighted avg       0.98      0.98      0.98      7865
#
# shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7833
#            1       0.00      0.00      0.00        32
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7767
#            1       0.10      0.05      0.07        98
#
#     accuracy                           0.98      7865
#    macro avg       0.54      0.52      0.53      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7531
#            1       0.25      0.04      0.07       334
#
#     accuracy                           0.95      7865
#    macro avg       0.61      0.52      0.52      7865
# weighted avg       0.93      0.95      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      5650
#            1       0.88      0.64      0.74      2215
#
#     accuracy                           0.87      7865
#    macro avg       0.88      0.80      0.83      7865
# weighted avg       0.87      0.87      0.87      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7202
#            1       0.89      0.54      0.67       663
#
#     accuracy                           0.96      7865
#    macro avg       0.92      0.77      0.83      7865
# weighted avg       0.95      0.96      0.95      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7130
#            1       0.74      0.63      0.68       735
#
#     accuracy                           0.94      7865
#    macro avg       0.85      0.80      0.82      7865
# weighted avg       0.94      0.94      0.94      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7782
#            1       0.38      0.31      0.34        83
#
#     accuracy                           0.99      7865
#    macro avg       0.69      0.65      0.67      7865
# weighted avg       0.99      0.99      0.99      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7122
#            1       0.84      0.82      0.83       743
#
#     accuracy                           0.97      7865
#    macro avg       0.91      0.90      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7718
#            1       0.46      0.33      0.38       147
#
#     accuracy                           0.98      7865
#    macro avg       0.72      0.66      0.69      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      7463
#            1       0.54      0.14      0.22       402
#
#     accuracy                           0.95      7865
#    macro avg       0.75      0.57      0.60      7865
# weighted avg       0.93      0.95      0.94      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      6343
#            1       0.77      0.37      0.50      1522
#
#     accuracy                           0.86      7865
#    macro avg       0.82      0.67      0.71      7865
# weighted avg       0.85      0.86      0.84      7865
#
# _______________________________________________________________________________________
# Classification report in total
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    250388
#            1       0.76      0.58      0.66     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.86      0.78      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# ____________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf', MultiOutputClassifier(estimator=AdaBoostClassifier()))])
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.258, test=0.250), total= 6.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  8.8min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.260, test=0.235), total= 5.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 16.3min remaining:    0.0s
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.262, test=0.246), total= 5.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.265, test=0.249), total= 6.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.259, test=0.262), total= 6.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.259, test=0.251), total= 6.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.262, test=0.238), total= 6.1min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.261, test=0.248), total= 5.7min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.264, test=0.249), total= 5.0min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.256, test=0.259), total= 5.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.281, test=0.263), total= 8.8min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.282, test=0.254), total= 7.9min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.282, test=0.259), total= 8.6min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.284, test=0.262), total= 8.5min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.279, test=0.272), total= 8.9min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.279, test=0.262), total= 8.9min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.276, test=0.246), total= 8.4min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.282, test=0.261), total= 9.1min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.285, test=0.258), total=10.2min
# [CV] clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.15, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.274, test=0.269), total=10.1min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.274, test=0.259), total= 8.5min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.278, test=0.251), total= 8.7min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True, score=(train=0.278, test=0.255), total= 8.8min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=True
# ...
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.273, test=0.244), total= 8.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.274, test=0.257), total= 6.7min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.280, test=0.254), total= 7.7min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=200, tfidf__use_idf=False, score=(train=0.271, test=0.272), total= 8.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.292, test=0.267), total= 9.7min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.293, test=0.255), total=10.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.297, test=0.262), total=11.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.299, test=0.259), total=11.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=True, score=(train=0.291, test=0.273), total= 9.4min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.293, test=0.268), total= 7.0min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.291, test=0.254), total= 7.3min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.297, test=0.266), total= 6.7min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.296, test=0.261), total= 7.4min
# [CV] clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False
# [CV]  clf__estimator__learning_rate=0.2, clf__estimator__n_estimators=300, tfidf__use_idf=False, score=(train=0.292, test=0.280), total= 6.5min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:
7865
# weighted avg       0.98      0.99      0.98      7865
#
# other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7531
#            1       0.35      0.03      0.06       334
#
#     accuracy                           0.96      7865
#    macro avg       0.66      0.52      0.52      7865
# weighted avg       0.93      0.96      0.94      7865
#
# weather_related
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      5650
#            1       0.88      0.61      0.72      2215
#
#     accuracy                           0.87      7865
#    macro avg       0.87      0.79      0.81      7865
# weighted avg       0.87      0.87      0.86      7865
#
# floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7202
#            1       0.90      0.51      0.65       663
#
#     accuracy                           0.95      7865
#    macro avg       0.93      0.75      0.81      7865
# weighted avg       0.95      0.95      0.95      7865
#
# storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7130
#            1       0.79      0.45      0.58       735
#
#     accuracy                           0.94      7865
#    macro avg       0.87      0.72      0.77      7865
# weighted avg       0.93      0.94      0.93      7865
#
# fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.50      0.13      0.21        83
#
#     accuracy                           0.99      7865
#    macro avg       0.75      0.57      0.60      7865
# weighted avg       0.99      0.99      0.99      7865
#
# earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7122
#            1       0.90      0.79      0.84       743
#
#     accuracy                           0.97      7865
#    macro avg       0.94      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# cold
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7718
#            1       0.63      0.21      0.32       147
#
#     accuracy                           0.98      7865
#    macro avg       0.81      0.60      0.65      7865
# weighted avg       0.98      0.98      0.98      7865
#
# other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7463
#            1       0.52      0.08      0.14       402
#
#     accuracy                           0.95      7865
#    macro avg       0.74      0.54      0.56      7865
# weighted avg       0.93      0.95      0.93      7865
#
# direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6343
#            1       0.79      0.35      0.48      1522
#
#     accuracy                           0.86      7865
#    macro avg       0.82      0.66      0.70      7865
# weighted avg       0.85      0.86      0.83      7865
#
# _______________________________________________________________________________________
# Classification report in total
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    250388
#            1       0.80      0.55      0.65     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.88      0.77      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# ____________________________________________________________________________________

# %%
#printout of each best estiamtor
for i in range(len(cv_list)):
    print(cv_list[i].best_estimator_)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(n_jobs=-1)))])
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier(n_estimators=200)))])
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(learning_rate=0.2,
#                                                                     n_estimators=300)))])

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
#assignment of each best estimator
rf_clf = cv_list[0].best_estimator_
gb_clf = cv_list[1].best_estimator_
ab_clf = cv_list[2].best_estimator_

best_estimators = [rf_clf, gb_clf, ab_clf]

# %%
#classification report for each best estimator to determine the best best estimator
for best_estimator in best_estimators:
    print(best_estimator)
    y_pred = pd.DataFrame(best_estimator.predict(X_test_array), columns=y_train.columns.tolist())
    print()
    print(classification_report(y_test.melt().value, y_pred.melt().value, zero_division=0))
    print('_______________________________________________________________________________________')
    print()
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier(n_jobs=-1)))])
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    250388
#            1       0.82      0.53      0.64     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.89      0.76      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=GradientBoostingClassifier(n_estimators=200)))])
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    250388
#            1       0.76      0.58      0.66     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.86      0.78      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________
#
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x0000022A5EAC5E50>)),
#                 ('tfidf', TfidfTransformer(use_idf=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(learning_rate=0.2,
#                                                                     n_estimators=300)))])
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97    250388
#            1       0.80      0.55      0.65     24887
#
#     accuracy                           0.95    275275
#    macro avg       0.88      0.77      0.81    275275
# weighted avg       0.94      0.95      0.94    275275
#
# _______________________________________________________________________________________

# %% [markdown]
# ## Model evaluation
#
# The classification report shows a slight better scoring (especialls the precision, recall and f1-score) for value = 1 for the Gradient Boosting Classifier.
# This model will be chosen as final model to implement

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
#exporting of best best estimator (gb_classifier)
dump(gb_clf, r'.\gb_classifier.joblib')
# Out:
# ['.\\gb_classifier.joblib']

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
